# %%
# Importing liabrary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('iris.csv')

# %%
# Print the 5 rows of the data set
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Print the basic information about the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Print the some basic state of the data set
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Show the no. of sample in each class
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# count the null values in the data set
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Making Histogram of Sepal Length Column
df['sepal_length'].hist( alpha=0.7, color='red', edgecolor='black', linewidth=1.2)
plt.xlabel('Sepal_length')
plt.ylabel('Count')
plt.title('Sepal Length Count')
# Out:
# Text(0.5, 1.0, 'Sepal Length Count')

# %%
# Making Histogram of Sepal Width Column
df['sepal_width'].hist(alpha=0.8, color='yellow', edgecolor='black', linewidth=1.2)
plt.xlabel('Sepal_width')
plt.ylabel('Count')
plt.title('Sepal Width Count')
# Out:
# Text(0.5, 1.0, 'Sepal Width Count')

# %%
# Making Histogram of Petal Length Column
df['petal_length'].hist(alpha=0.7, color='green', edgecolor='black', linewidth=1.2)
plt.xlabel('petal_length')
plt.ylabel('Count')
plt.title('Petal Length Count')
# Out:
# Text(0.5, 1.0, 'Petal Length Count')

# %%
# # Making Histogram of Petal Width Column
df['petal_width'].hist(alpha=0.5, color='black', edgecolor='black', linewidth=1.2)
plt.xlabel('Petal_width')
plt.ylabel('Count')
plt.title('Petal Width Count')
# Out:
# Text(0.5, 1.0, 'Petal Width Count')

# %% [markdown]
# # PLotting scatterplot

# %%
colors = ['red','green','blue']
species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
# Plotting scatterplot for Sepal Length and Sepal Width Column
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['sepal_length'],x['sepal_width'], c = colors[i], label=species[i])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.grid(True)

# %%
# Plotting scatterplot for Petal Length and Petal Width Column
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['petal_length'],x['petal_width'], c = colors[i], label=species[i])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend()
plt.grid(True)

# %%
# Plotting scatterplot for Sepal Length and Petal Length Column
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['sepal_length'],x['petal_length'], c = colors[i], label=species[i])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend()
plt.grid(True)

# %%
# Plotting scatterplot for Sepal Width and Petal Width Column
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['sepal_width'],x['petal_width'], c = colors[i], label=species[i])
plt.xlabel('Sepal width')
plt.ylabel('Petal Width')
plt.legend()
plt.grid(True)

# %% [markdown]
# # LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['species'] = le.fit_transform(df['species'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df1 = df.drop(columns=['species'])
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
import seaborn as sns
corr = df1.corr()
fig, ax = plt.subplots(figsize=(5,4))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Model Training

# %%
# imoorting train test split module
from sklearn.model_selection import train_test_split

# %%
# Selcted features and targets columns
X = df.drop(columns=['species'])
Y = df['species']

# %%
# Split the data set into train and test part
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %% [markdown]
# # Logistic Regression
# It's a type of regression analysis that's suitable for predicting the probability of an instance belonging to a particular class

# %%
# Importing Logistic regressiion
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# model training
model.fit(X_train, y_train)
# Out:
# C:\Users\Afsar Ali\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Print the accuracy of the model using logisticRegression
print("Accuracy:", model.score(X_test, y_test) * 100)
# Out:
# Accuracy: 100.0

# %% [markdown]
# # KNeighborsClassifier
# It is used to classify data points based on the majority class of their k-nearest neighbors in a feature space.

# %%
# Importing KNN KNearest NeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier()

# %%
# Model training
model1.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Print the accuracy of the model using KNeighborsClassifier
print("Accuracy:", model1.score(X_test, y_test) * 100)
# Out:
# Accuracy: 100.0

# %% [markdown]
# # DecisionTreeClassifier
# It's a type of supervised learning algorithm that makes predictions based on a sequence of decisions made on features.

# %%
# Importing decision tree classifier
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()

# %%
# Model training
model2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Print the accuracy of the model using DecisionTreeClassifier
print("Accuracy:", model2.score(X_test, y_test) * 100)
# Out:
# Accuracy: 95.55555555555556
